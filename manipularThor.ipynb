# %%
from ai2thor.controller import Controller
from ai2thor.platform import CloudRendering
from butler.controller import PrimitiveButController as Controller
from butler.controller import MultiButController as MultiController
import matplotlib.pyplot as plt
from butler.utils import *
import pandas as pd

# %%
controller = Controller(scene="FloorPlan10")

# %%
event = controller.step(action="GetMapViewCameraProperties")
controller.step(
    action="AddThirdPartyCamera",
    **event.metadata["actionReturn"]
)
# Out:
# <ai2thor.server.Event at 0x7eff195328b0
#     .metadata["lastAction"] = AddThirdPartyCamera
#     .metadata["lastActionSuccess"] = True
#     .metadata["errorMessage"] = "
#     .metadata["actionReturn"] = None
# >

# %%
controller.render_third_party_camera();

# %%
controller.stored_frames
# Out:
# {}
